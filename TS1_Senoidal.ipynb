# %% [markdown]
# # Tarea 1: Función senoidal
# ##### Florencia Alvarez
# ##### 167.262-9

# %% [markdown]
# En este primer trabajo comenzaremos por diseñar un generador de señales que utilizaremos en las primeras simulaciones que hagamos. La primer tarea consistirá en programar una función que genere señales senoidales y que permita parametrizar:
#
#     la amplitud máxima de la senoidal (volts)
#     su valor medio (volts)
#     la frecuencia (Hz)
#     la fase (radianes)
#     la cantidad de muestras digitalizada por el ADC (# muestras)
#     la frecuencia de muestreo del ADC.
#
# es decir que la función que uds armen debería admitir se llamada de la siguiente manera
#
# tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs)
#
# Recuerden que tanto xx como tt deben ser vectores de Nx1. Puede resultarte útil el módulo de visualización matplotlib.pyplot donde encontrarán todas las funciones de visualización estilo Matlab. Para usarlo:
#
# import matplotlib.pyplot as plt
#
# plt.plot(tt, xx)

# %%
import numpy as np
import matplotlib.pyplot as plt

N= 1000 #
fs= 1000 #
fo = 1 #
   
def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs):
    tt= np.arange(stop=1,step=ts)
    
    xx = vmax * np.sin(tt*2*np.pi*ff + ph) + dc

    return tt, xx
    

ts = 1/fs #s

tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs)

plt.title('Funcion senoidal')
plt.xlabel('tiempo [s]')
plt.ylabel('V(t) [V]')
plt.plot(tt, xx, color = 'fuchsia')

# %% [markdown]
# Para el desarrollo de esta actividad primero se armó un vector de tiempo que dure 1 segundo con un paso de ts=1/fs.
# Luego, se continuó con el armado del vector de la función xx, tal y como se pedía en la consigna.
# A continuación, se creó el prototipo de mi_funcion_sen, incluyendo lo anteriormente mencionado
# Una vez hecho esto, se realizó el llamado a la función creada.
# Por último, se graficó la señal, incorporando el título y nombre de los ejes con sus respectivas unidades correspondientes.

# %% [markdown]
# Una vez realizado el gráfico de la función senoidal de f= 1[Hz], se modificó la frecuencia para ver cómo afecta esta al gráfico.

# %% [markdown]
# | f | ciclos/s | Muestras/ciclo |
# | --- | --- | --- |
# | 1 | 1 | 1000 |
# | 2 | 2 | 1000 |
# | 3 | 3 | 1000/3 |
# | 100 | 100 | 2 |
# | 200 | 200 | 5 |
# | 500 | 500| 2 |

# %%
tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 2, ph=0, nn = N, fs = fs)

plt.title('Funcion senoidal f=2 [Hz]')
plt.xlabel('tiempo [s]')
plt.ylabel('V(t) [V]')
plt.plot(tt, xx, color = 'cyan')

# %%
tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 3, ph=0, nn = N, fs = fs)

plt.title('Funcion senoidal f=3 [Hz]')
plt.xlabel('tiempo [s]')
plt.ylabel('V(t) [V]')
plt.plot(tt, xx, color = 'blue')

# %%
tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 100, ph=0, nn = N, fs = fs)

plt.title('Funcion senoidal f=100 [Hz]')
plt.xlabel('tiempo [s]')
plt.ylabel('V(t) [V]')
plt.plot(tt, xx, color = 'purple')

# %%
tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 200, ph=0, nn = N, fs = fs)

plt.title('Funcion senoidal f=200 [Hz]')
plt.xlabel('tiempo [s]')
plt.ylabel('V(t) [V]')
plt.plot(tt, xx, color = 'orange')

# %%
tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 500, ph=0, nn = N, fs = fs)

plt.title('Funcion senoidal f=500 [Hz]')
plt.xlabel('tiempo [s]')
plt.ylabel('V(t) [V]')
plt.plot(tt, xx, color = 'green')

# %%
tt, xx = mi_funcion_sen( vmax = 1, dc = 0, ff = 700, ph=0, nn = N, fs = fs)

plt.title('Funcion senoidal f=700 [Hz]')
plt.xlabel('tiempo [s]')
plt.ylabel('V(t) [V]')
plt.plot(tt, xx, color = 'maroon')

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# Como era de esperar, se observa a}que al aumentar la frecuencia se pueden apreciar más ciclos en el mismo intervalo de tiempo, es decir, que disminuye el periodo de la señal a estudiar y por lo tanto disminuye la cantidad de muestras por ciclo.
# Además, por el Teorema de Nyquist , se sabe que la frecuencia de muestreo (fs) debe ser al menos el doble de la frecuencia de la señal. Al graficar una senoidal para f=fs, es decir, justo sobre la frecuencia de Nyquist (gráfico verde) solo se cuentan con 2 muestras por ciclo (una positiva y una negativa). Por este motivo, no es posible reconstruir la señal ya que no se cuenta con información suficiente. Por último, se graficó una senoidal con una frecuencia mayor a la frecuencia de Nyquist donde se puede observar que se produce aliasing y por lo tanto la señal no puede ser reconstruida.
